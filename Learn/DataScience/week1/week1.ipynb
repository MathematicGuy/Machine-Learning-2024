# %% [markdown]
# ### Ambari dashboard
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# **Screenshot the content of the root folder**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Install File using cmd command:
