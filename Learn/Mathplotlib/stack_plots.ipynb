# %% [markdown]
# # Stack Plot
#  Use when you want to display results overtime of a certain individual. e.g. basketball player score over time

# %%
from matplotlib import pyplot as plt
plt.style.use("seaborn-v0_8-paper") # set style to xkcd

# %%
minutes = [1,2,3,4,5,6,7,8,9]

player1 = [1, 1, 2, 3, 4, 4, 4, 5, 5]
player2 = [1, 1, 1, 2, 2, 2, 3, 3, 4]
player3 = [1, 1, 2, 2, 3, 3, 3, 3, 3]

# plt.pie([1, 1, 1], labels=["Player 1", "Player 2", "Player 3"])
labels = ['player1','player2','player3']
colors = ['#6d904f', '#fc4f30', '#008fd5']

plt.stackplot(minutes, player1, player2, player3, labels=labels)
plt.legend() # loc (labels location) = 'upper left', 'upper right', 'lower left', 'lower right'
plt.title("My Awesome Stack Plot")
plt.tight_layout()
plt.show()

# %%
minutes = [1,2,3,4,5,6,7,8,9]

player1 = [9, 8, 7, 6, 5, 4, 3, 2, 1]
player2 = [1, 2, 2, 2, 3, 4, 5, 6, 7]
player3 = [1, 2, 3, 4, 5, 6, 7, 8, 9]

# plt.pie([1, 1, 1], labels=["Player 1", "Player 2", "Player 3"])
labels = ['player1','player2','player3']
colors = ['#6d904f', '#fc4f30', '#008fd5']

plt.stackplot(minutes, player1, player2, player3, labels=labels)
plt.legend(loc=(0.06, 0.02)) # loc (labels location) = 'upper left', 'upper right', 'lower left', 'lower right'
plt.title("My Awesome Stack Plot")
plt.tight_layout()
plt.show()
