# %%
import cv2 as cv
import numpy as np

# %%
img = cv.imread('Resources/furina.png') # B, G, R
assert img is not None, "File Could not be Read, check path with os.path.exists()"

# %%
from matplotlib import pyplot as plt

plt.subplot(121)
grey = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
plt.imshow(grey)

# %%
px = img[100, 100]
print(px)
# Out:
# [117 118 160]

# %%
# blue = img[100, 100, 0]
# print(blue)

# %%
test = img.copy()
test[100, 800] = [255, 255, 255]
print(test[100, 100])
print(test.shape)
print(test.dtype)
plt.imshow(test)
# Out:
# [117 118 160]
# (816, 1006, 3)
# uint8

# %% [markdown]
# ### HW
# Read about Color Space, Color Space Conversion
#
# How Human Vision relate to Computer Vision

# %%
yrange=250
xrange=300
luv = img[500:500+yrange, 500:500+xrange]
img[50:50+yrange, 350:650] = luv
plt.subplot(121)
plt.imshow(img)

# %%
b, g, r = cv.split(img)
img = cv.merge((r, g, b))
plt.imshow(img)

# %%
b = img[:,:,0]

# %%
img[:,:,2] = 0

# %%
plt.imshow(img)
