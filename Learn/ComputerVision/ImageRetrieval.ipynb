# %%
import cv2 as cv
import numpy as numpy
import matplotlib.pyplot as plt

# %%
gray_image = cv.imread('Resources/furina.png', cv.IMREAD_GRAYSCALE)

# %%
plt.imshow(gray_image, cmap='gray')

# %% [markdown]
# # Calculate Histogram
# Calculates the histogram of an image. A Histogram is the frequency distribution of the grey levels pixel value from [0, 255]

# %%
hist = cv.calcHist([gray_image], [0], )
